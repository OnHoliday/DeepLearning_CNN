# %%
from utils import *
# Out:
# Using TensorFlow backend.

# %%
import glob
import matplotlib
from matplotlib import pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import imageio as im
from keras import models
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
from keras.layers import Dropout
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint

from utils import *
from cnn import CnnSolver
class_mode = 'categorical'  #'sparse'      # 'binary','categorical, 'other'


# images = []
# for img_path in glob.glob(r'D:\DeepLearningProject\multiple_output\man_asian\*.jpg'):
#     images.append(mpimg.imread(img_path))

# plt.figure(figsize=(20, 10))
# columns = 5
# for i, image in enumerate(images):
#     plt.subplot(len(images) / columns + 1, columns, i + 1)
#     plt.imshow(image)

model1 = CnnSolver(class_mode, 'testing_age__2ConvPool___0')
model1.load_model('mse', ['mae'])


layer_outputs = [layer.output for layer in model1.model.layers[:3]]
# Extracts the outputs of the top 12 layers

# activation_model = models.Model(inputs=model1.input, outputs=layer_outputs)
# Creates a model that will return these outputs, given the model input

wd = get_path()
path1 = wd / 'UTKFace_pred'  # for cropped

onlyfiles = [f for f in listdir(path1) if isfile(join(path1, f))]
random_pic = Path(random.choice(onlyfiles))
path = path1 / random_pic


img = image.load_img(path, target_size=(128, 128))
img_tensor = image.img_to_array(img)
img_tensor = np.expand_dims(img_tensor, axis=0)
img_tensor /= 255.0

plt.interactive(False)
plt.imshow(img_tensor[0])
plt.show()
# Out:
# Loaded model from disk
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_11 (Conv2D)           (None, 128, 128, 32)      896
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 64, 64, 32)        9248
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 32768)             0
# _________________________________________________________________
# dense_9 (Dense)              (None, 1024)              33555456
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 1024)              0
# ...

# %%
pic = 11

# %%
wd = get_path()
path1 = wd / 'UTKFace_pred'  # for cropped

onlyfiles = [f for f in listdir(path1) if isfile(join(path1, f))]
random_pic = onlyfiles[pic] #Path(random.choice(onlyfiles))
path = path1 / random_pic


img = image.load_img(path, target_size=(4, 4))
img_tensor = image.img_to_array(img)
img_tensor = np.expand_dims(img_tensor, axis=0)
img_tensor /= 255.0

plt.interactive(False)
plt.imshow(img_tensor[0])
plt.show()

# %%
wd = get_path()
path1 = wd / 'UTKFace_pred'  # for cropped

onlyfiles = [f for f in listdir(path1) if isfile(join(path1, f))]
random_pic = onlyfiles[pic] #Path(random.choice(onlyfiles))
path = path1 / random_pic


img = image.load_img(path, target_size=(8, 8))
img_tensor = image.img_to_array(img)
img_tensor = np.expand_dims(img_tensor, axis=0)
img_tensor /= 255.0

plt.interactive(False)
plt.imshow(img_tensor[0])
plt.show()

# %%
wd = get_path()
path1 = wd / 'UTKFace_pred'  # for cropped

onlyfiles = [f for f in listdir(path1) if isfile(join(path1, f))]
random_pic = onlyfiles[pic] #Path(random.choice(onlyfiles))
path = path1 / random_pic


img = image.load_img(path, target_size=(16, 16))
img_tensor = image.img_to_array(img)
img_tensor = np.expand_dims(img_tensor, axis=0)
img_tensor /= 255.0

plt.interactive(False)
plt.imshow(img_tensor[0])
plt.show()

# %%
wd = get_path()
path1 = wd / 'UTKFace_pred'  # for cropped

onlyfiles = [f for f in listdir(path1) if isfile(join(path1, f))]
random_pic = onlyfiles[pic] #Path(random.choice(onlyfiles))
path = path1 / random_pic


img = image.load_img(path, target_size=(32, 32))
img_tensor = image.img_to_array(img)
img_tensor = np.expand_dims(img_tensor, axis=0)
img_tensor /= 255.0

plt.interactive(False)
plt.imshow(img_tensor[0])
plt.show()

# %%
wd = get_path()
path1 = wd / 'UTKFace_pred'  # for cropped

onlyfiles = [f for f in listdir(path1) if isfile(join(path1, f))]
random_pic = onlyfiles[pic] #Path(random.choice(onlyfiles))
path = path1 / random_pic


img = image.load_img(path, target_size=(64, 64))
img_tensor = image.img_to_array(img)
img_tensor = np.expand_dims(img_tensor, axis=0)
img_tensor /= 255.0

plt.interactive(False)
plt.imshow(img_tensor[0])
plt.show()

# %%
wd = get_path()
path1 = wd / 'UTKFace_pred'  # for cropped

onlyfiles = [f for f in listdir(path1) if isfile(join(path1, f))]
random_pic = onlyfiles[pic] #Path(random.choice(onlyfiles))
path = path1 / random_pic


img = image.load_img(path, target_size=(128, 128))
img_tensor = image.img_to_array(img)
img_tensor = np.expand_dims(img_tensor, axis=0)
img_tensor /= 255.0

plt.interactive(False)
plt.imshow(img_tensor[0])
plt.show()

# %%
wd = get_path()
path1 = wd / 'UTKFace_pred'  # for cropped

onlyfiles = [f for f in listdir(path1) if isfile(join(path1, f))]
random_pic = onlyfiles[pic] #Path(random.choice(onlyfiles))
path = path1 / random_pic


img = image.load_img(path, target_size=(256, 256))
img_tensor = image.img_to_array(img)
img_tensor = np.expand_dims(img_tensor, axis=0)
img_tensor /= 255.0

plt.interactive(False)
plt.imshow(img_tensor[0])
plt.show()

# %%
img = image.load_img(path, target_size=(128, 128))
img_tensor = image.img_to_array(img)
img_tensor = np.expand_dims(img_tensor, axis=0)
img_tensor /= 255.0
print(img_tensor)
# Out:
# [[[[0.07450981 0.05098039 0.05882353]
#    [0.07843138 0.0627451  0.06666667]
#    [0.08627451 0.07058824 0.07450981]
#    ...
#    [0.07058824 0.06666667 0.05882353]
#    [0.06666667 0.0627451  0.05490196]
#    [0.06666667 0.0627451  0.05490196]]
#
#   [[0.09803922 0.07450981 0.08235294]
#    [0.09411765 0.07843138 0.08235294]
#    [0.09803922 0.08235294 0.08627451]
#    ...
#    [0.07058824 0.06666667 0.05882353]
#    [0.06666667 0.0627451  0.05490196]
#    [0.06666667 0.0627451  0.05490196]]
#
#   [[0.10588235 0.08235294 0.08235294]
#    [0.09803922 0.08235294 0.08627451]
#    [0.09803922 0.08235294 0.08627451]
#    ...
#    [0.07058824 0.06666667 0.05882353]
#    [0.06666667 0.0627451  0.05490196]
#    [0.06666667 0.0627451  0.05490196]]
#
#   ...
#
#   [[0.13725491 0.09803922 0.09019608]
#    [0.13725491 0.09803922 0.09019608]
#    [0.14117648 0.10196079 0.09411765]
#    ...
#    [0.08235294 0.07843138 0.0627451 ]
#    [0.07843138 0.07450981 0.05882353]
# ...

# %%
layer_outputs = [layer.output for layer in model1.model.layers[:4]] 
print(layer_outputs)
# Extracts the outputs of the top 12 layers

activation_model = models.Model(inputs=model1.model.input, outputs=layer_outputs) 

activations = activation_model.predict(img_tensor) 
# print(activations)
# # Returns a list of five Numpy arrays: one array per layer activation

first_layer_activation = activations[0]
print(first_layer_activation.shape)

# (1, 28, 28, 32)

plt.matshow(first_layer_activation[0, :, :, 5], cmap='viridis')
# Out:
# [<tf.Tensor 'conv2d_11_8/Relu:0' shape=(?, 128, 128, 32) dtype=float32>, <tf.Tensor 'max_pooling2d_8_8/MaxPool:0' shape=(?, 64, 64, 32) dtype=float32>, <tf.Tensor 'conv2d_12_8/Relu:0' shape=(?, 64, 64, 32) dtype=float32>, <tf.Tensor 'max_pooling2d_9_8/MaxPool:0' shape=(?, 32, 32, 32) dtype=float32>]
# (1, 128, 128, 32)

# %%
layer_names = []
for layer in model1.model.layers[:4]:
    layer_names.append(layer.name)
images_per_row = 16
for layer_name, layer_activation in zip(layer_names, activations):  # Displays the feature maps
    n_features = layer_activation.shape[-1]  # Number of features in the feature map
    size = layer_activation.shape[1]  # The feature map has shape (1, size, size, n_features).
    n_cols = n_features // 16  # Tiles the activation channels in this matrix
    display_grid = np.zeros((size * n_cols, images_per_row * size))
    for col in range(n_cols):  # Tiles each filter into a big horizontal grid
        for row in range(images_per_row):
            channel_image = layer_activation[0,
                            :, :,
                            col * images_per_row + row]
            chajupyternnel_image -= channel_image.mean()  # Post-processes the feature to make it visually palatable
            channel_image /= channel_image.std()
            channel_image *= 64
            channel_image += 128
            channel_image = np.clip(channel_image, 0, 255).astype('uint8')
            display_grid[col * size: (col + 1) * size,  # Displays the grid
            row * size: (row + 1) * size] = channel_image
    scale = 1. / size
    plt.figure(figsize=(scale * display_grid.shape[1],
                        scale * display_grid.shape[0]))
    plt.title(layer_name)
    plt.grid(False)
    plt.imshow(display_grid, aspect='auto', cmap='viridis') #viridis
# Out:
# C:\Users\Konrad\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: RuntimeWarning: invalid value encountered in true_divide
#   app.launch_new_instance()
